# %% [markdown]
# Book 4
#
# token
# ('the', 2435),
#  ('of', 1193),
#  ('and', 927),
#  ('to', 866),
#  ('in', 477),
#  ('a', 372),
#  ('was', 344),
#  ('that', 338),
#  ('they', 331),
#  ('their', 292),
#  ('were', 266),
#
#  type
#  ('Messenians', 192),
#  ('Lacedaemonians', 143),
#  ('son', 120),
#  ('Aristomenes', 82),
#  ('men', 81),
#  ('war', 66),
#  ('Messene', 56),
#  ('called', 55),
#  ('time', 53),
#  ('said', 53),
#  ('Messenian', 50),
#
#  lemmata
#  ('Messenians', 192),
#  ('Lacedaemonians', 143),
#  ('son', 142),
#  ('man', 119),
#  ('come', 83),
#  ('Aristomenes', 75),
#  ('say', 67),
#  ('war', 67),
#  ('call', 60),
#  ('time', 56),
#  ('Messene', 53),
#
#  lexeme
#  (('Messenians', <spacy.lexeme.Lexeme at 0x796316dae300>), 192),
#  (('Lacedaemonians', <spacy.lexeme.Lexeme at 0x79631864fcc0>), 143),
#  (('son', <spacy.lexeme.Lexeme at 0x7963185c6c40>), 120),
#  (('Aristomenes', <spacy.lexeme.Lexeme at 0x796316de8f80>), 82),
#  (('men', <spacy.lexeme.Lexeme at 0x796316dafdc0>), 81),
#  (('war', <spacy.lexeme.Lexeme at 0x796316da8e40>), 66),
#  (('Messene', <spacy.lexeme.Lexeme at 0x7963185c7c40>), 56),
#  (('called', <spacy.lexeme.Lexeme at 0x796316d9d780>), 55),
#  (('time', <spacy.lexeme.Lexeme at 0x796316d9fc40>), 53),
#  (('said', <spacy.lexeme.Lexeme at 0x796316dad100>), 53),
#  (('Messenian', <spacy.lexeme.Lexeme at 0x796316dada00>), 50),

# %% [markdown]
# Book 2
#
# token
# ('the', 2638),
#  ('of', 1596),
#  ('and', 950),
#  ('to', 851),
#  ('a', 695),
#  ('is', 571),
#  ('in', 448),
#  ('was', 419),
#  ('that', 407),
#  ('they', 298),
#  ('by', 288),
#  ('from', 251),
#
#  type
#  ('son', 200),
#  ('sanctuary', 140),
#  ('called', 122),
#  ('temple', 114),
#  ('image', 84),
#  ('place', 80),
#  ('Argives', 69),
#  ('land', 59),
#  ('Zeus', 56),
#  ('Apollo', 56),
#  ('city', 54),
#  ('said', 51),
#  ('daughter', 50),
#  ('Poseidon', 47),
#
#  lemmata
#  ('son', 236),
#  ('sanctuary', 150),
#  ('call', 125),
#  ('image', 125),
#  ('temple', 117),
#  ('place', 90),
#  ('come', 78),
#  ('say', 77),
#  ('give', 68),
#  ('land', 62),
#  ('city', 62),
#  ('daughter', 60),
#
#  lexeme
# (('son', <spacy.lexeme.Lexeme at 0x796318a16a00>), 200),
#  (('sanctuary', <spacy.lexeme.Lexeme at 0x79631660c780>), 140),
#  (('called', <spacy.lexeme.Lexeme at 0x796318a16980>), 122),
#  (('temple', <spacy.lexeme.Lexeme at 0x79631660d280>), 114),
#  (('image', <spacy.lexeme.Lexeme at 0x796316615cc0>), 84),
#  (('place', <spacy.lexeme.Lexeme at 0x796317149800>), 80),
#  (('Argives', <spacy.lexeme.Lexeme at 0x79631661fb00>), 69),
#  (('land', <spacy.lexeme.Lexeme at 0x79631713dbc0>), 59),
#  (('Zeus', <spacy.lexeme.Lexeme at 0x796318a17080>), 56),
#  (('Apollo', <spacy.lexeme.Lexeme at 0x79631661a200>), 56),
#  (('city', <spacy.lexeme.Lexeme at 0x79631660c0c0>), 54),
#  (('said', <spacy.lexeme.Lexeme at 0x79631714bec0>), 51),
#  (('daughter', <spacy.lexeme.Lexeme at 0x79631714b980>), 50),
#  (('Poseidon', <spacy.lexeme.Lexeme at 0x796317149400>), 47),

# %% [markdown]
# Book 6
#
# token
# ('the', 2060),
#  ('of', 1285),
#  ('and', 629),
#  ('a', 471),
#  ('to', 427),
#  ('in', 422),
#  ('was', 309),
#  ('is', 297),
#  ('at', 269),
#  ('by', 267),
#  ('his', 214),
#  ('that', 212)
#
#  type
#  ('statue', 172),
#  ('son', 161),
#  ('won', 128),
#  ('Olympia', 89),
#  ('race', 69),
#  ('Eleans', 67),
#  ('boys', 65),
#  ('dedicated', 64),
#  ('Elis', 63),
#  ('victory', 56),
#  ('men', 53),
#  ('boxing', 53),
#  ('victories', 52),
#  ('match', 52),
#  ('man', 45),
#  ('inscription', 42),
#  ('chariot', 42),
#
#  lemmata
#  ('statue', 209),
#  ('son', 176),
#  ('win', 145),
#  ('victory', 109),
#  ('man', 100),
#  ('Olympia', 89),
#  ('boy', 84),
#  ('race', 76),
#  ('Eleans', 67),
#  ('dedicate', 65),
#  ('Elis', 63),
#  ('match', 54),
#  ('horse', 52),
#  ('stand', 50),
#  ('say', 48),
#  ('chariot', 46),
#  ('inscription', 45),
#
#  lexeme
#  (('statue', <spacy.lexeme.Lexeme at 0x79631714bac0>), 172),
#  (('son', <spacy.lexeme.Lexeme at 0x79631660edc0>), 161),
#  (('won', <spacy.lexeme.Lexeme at 0x796317148500>), 128),
#  (('Olympia', <spacy.lexeme.Lexeme at 0x79631660d580>), 89),
#  (('race', <spacy.lexeme.Lexeme at 0x7963166168c0>), 69),
#  (('Eleans', <spacy.lexeme.Lexeme at 0x79631660d940>), 67),
#  (('boys', <spacy.lexeme.Lexeme at 0x79631660dd80>), 65),
#  (('dedicated', <spacy.lexeme.Lexeme at 0x796316617c40>), 64),
#  (('Elis', <spacy.lexeme.Lexeme at 0x796316614e80>), 63),
#  (('victory', <spacy.lexeme.Lexeme at 0x79631660de40>), 56),
#  (('men', <spacy.lexeme.Lexeme at 0x796317148ec0>), 53),
#  (('boxing', <spacy.lexeme.Lexeme at 0x79631660de00>), 53),
#  (('victories', <spacy.lexeme.Lexeme at 0x796317148bc0>), 52),
